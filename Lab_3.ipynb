# %% [markdown]
# <a href="https://colab.research.google.com/github/Allabhi/FMML_labs_projects/blob/main/Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-13 14:26:50--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   165MB/s    in 0.4s
#
# 2025-03-13 14:26:52 (165 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 12636  1803.08021v1  Over the course of the past decade, a variety ...  stat
# 24250   1112.5638v1  Transformation-invariant analysis of signals o...    cs
# 37404  1706.01574v2  A significant amount of search queries origina...    cs
# 7947   1608.00781v2  I introduce a new distributed system for effec...    cs
# 13223  cs/0201005v2  We provide a new representation-independent fo...    cs
# ...             ...                                                ...   ...
# 7490   1801.05512v1  Survival analysis/time-to-event models are ext...  stat
# 5401    1308.3818v1  A theoretical study is presented for a simple ...    cs
# 19881   1303.1502v1  To determine the value of perfect information ...    cs
# 2499    1409.0791v1  Map matching of the GPS trajectory serves the ...  stat
# 21744   1406.3711v1  Despite the fact that they do not consider the...  stat
#
#                                                    title  year  \
# 12636  Error Estimation for Randomized Least-Squares ...  2018
# 24250  Discretization of Parametrizable Signal Manifolds  2011
# 37404  Extracting Hierarchies of Search Tasks & Subta...  2017
# 7947   Horn: A System for Parallel Training and Regul...  2016
# 13223                           Sharpening Occam's Razor  2002
# ...                                                  ...   ...
# 7490   Deep Neural Networks for Survival Analysis Bas...  2018
# 5401                        Reference Distance Estimator  2013
# 19881  Incremental computation of the value of perfec...  2013
# 2499   Feature Selection in Conditional Random Fields...  2014
# 21744      Dimensionality reduction for time series data  2014
#
#                                                 keywords
# 12636  [randomized, algorithms, computing, approximat...
# 24250  [transformation, invariant, computation, trans...
# 37404  [significant, originate, information, experien...
# 7947   [introduce, distributed, effective, regularizi...
# 13223  [representation, independent, formulation, kol...
# ...                                                  ...
# 7490   [analysistime, extremely, companies, therefore...
# 5401   [theoretical, presented, classifier, reference...
# 19881  [determine, information, influence, informatio...
# 2499   [trajectory, recovering, observations, fundame...
# 21744  [dimensionality, reduction, techniques, introd...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 12636    [randomized, algorithms, computing, approximat...
# 24250    [transformation, invariant, computation, trans...
# 37404    [significant, originate, information, experien...
# 7947     [introduce, distributed, effective, regularizi...
# 13223    [representation, independent, formulation, kol...
#                                ...
# 25368    [recognition, conditions, traditional, statist...
# 21936    [introduce, parallelizing, inference, spatiall...
# 13085    [convergence, properties, algorithm, introduce...
# 2153     [convolutional, performing, supervised, unlabe...
# 1116     [stochastic, transition, application, generate...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8655 words.
# Out of those 4528 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ca54aab6-fbc3-4a93-8b77-c1dd140cc6ad" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ca54aab6-fbc3-4a93-8b77-c1dd140cc6ad")) {                    Plotly.newPlot(                        "ca54aab6-fbc3-4a93-8b77-c1dd140cc6ad",                        [{"x":["considerable","estimates","algorithm","underlying","bootstrap","algorithms","standpoint","preliminary","solutions","posteriori","computation","precisely","consistency","flexibility","approximate","numerically","alternative","empirical","sketching","computing","difficult","tolerance","longstanding","theoretical","practical","estimation","effectiveness","consequently","randomized","demonstrate","qualitative","transformation","geometric","experimental","asymmetric","represent","outperforms","registration","performance","information","selection","manifolds","particular","efficient","invariant","individually","depending","applications","approximation","essential","representation","distribution","parameterization","additional","distances","minimizing","different","performing","optimization","structures","transformed","comparison","classification","discretization","representing","prediction","crowdsourced","experiments","extraction","nonparametric","satisfaction","originate","associated","extracting","hierarchies","naturalistic","recommendations","personalization","quantitative","highlight","considering","significant","importance","suggestions","providing","important","hierarchy","experience","methodologies","representations","regularizing","including","implementation","strategies","collective","parallelization","effective","distributed","partitioning","introduce","performed","architectures","handwritten","specifically","assumptions","complexity","independent","formulation","publication","kolmogorov","threshold","posteriors","stochastic","incremental","constrained","approximations","assignments","observation","probability","posterior","variational","distributions","integrates","typically","appearing","evaluating","regresses","magnitude","estimating","leveraging","techniques","coefficients","expressions","demonstrating","estimated","unprecedented","collecting","detection","measuring","discriminative","benchmarks","alternatives","intensities","advantage","recognition","conditions","robustness","expression","discriminate","outperform","imbalance","perturbing","separating","characterized","resolution","perturbation","identifying","classifiers","diversification","challenge","dependence","datapoints","misclassified","imbalanced","generalization","challenging","community","corrected","benchmark","numerical","detecting","employing","interpretable","fundamental","clustering","communities","generative","asymptotically","overlapping","memberships","simulated","consistent","recovering","extensive","interesting","beneficial","instances","allocation","individual","dirichlet","intractable","inference","investigate","properties","environments","particularly","streaming","contemporary","objective","attachment"],"y":[35,74,833,121,4,585,2,42,144,10,157,18,68,32,86,10,89,159,3,133,135,9,2,156,138,198,208,30,25,584,58,76,74,424,15,114,237,27,877,684,153,18,289,419,69,18,36,441,117,74,343,209,4,115,35,52,726,83,336,124,30,123,505,7,71,228,7,631,132,22,22,5,119,56,16,4,17,3,67,27,65,253,78,9,80,358,39,37,21,240,10,254,144,104,10,8,268,99,16,322,121,112,32,175,67,234,111,96,8,6,40,6,135,22,72,32,12,66,156,33,57,127,25,103,9,61,3,50,64,57,377,34,45,19,57,11,17,352,26,98,86,30,7,104,367,137,92,47,13,114,8,5,9,43,108,20,75,116,2,162,32,1,4,10,96,262,68,10,225,84,74,26,32,79,137,20,137,13,22,2,60,91,23,164,67,20,96,27,119,24,27,201,138,226,101,73,12,8,163,2],"type":"bar"},{"x":["considerable","estima ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4528,), (4528, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.79

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.7142857142857142);'>Curriculum</span> <span style=''>Dropout</span> <br/><br/><span style=''>Dropout</span> <span style=''>is</span> <span style=''>a</span> <span style=''>very</span> <span style='background-color:rgba(0, 255, 0, 0.3201970443349753);'>effective</span> <span style=''>way</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularizing</span> <span style=''>neural</span> <span style=''>networks</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Stochastically</span> <span style=''>dropping</span> <span style=''>out</span> <span style=''>units</span> <span style=''>with</span> <span style=''>a</span> <span style=''>certain</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>discourages</span> <span style=''>over</span> <span style=''>specific</span> <span style=''>co</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>adaptations</span> <span style=''>of</span> <span style=''>feature</span> <span style='background-color:rgba(0, 255, 0, 0.6190476190476191);'>detectors</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>preventing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>overfitting</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3892215568862277);'>improving</span> <span style=''>network</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalization</span> <span style=''>Besides</span> <span style=''>Dropout</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpreted</span> <span style=''>as</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.31746031746031744);'>approximate</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>aggregation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>technique</span> <span style=''>where</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exponential</span> <span style=''>number</span> <span style=''>of</span> <span style=''>smaller</span> <span style=''>networks</span> <span style=''>are</span> <span style=''>averaged</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style=''>get</span> <span style=''>a</span> <span style=''>more</span> <span style=''>powerful</span> <span style=''>ensemble</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>using</span> <span style=''>a</span> <span style=''>fixed</span> <span style=''>dropout</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>during</span> <span style=''>training</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>suboptimal</span> <span style=''>choice</span> <span style=''>We</span> <span style=''>thus</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666667);'>scheduling</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>retaining</span> <span style=''>neurons</span> <span style=''>in</span> <span style=''>the</span> <span style=''>network</span> <span style=''>This</span> <span style=''>induces</span> <span style=''>an</span> <span style=''>adaptive</span> <span style='background-color:rgba(255, 0, 0, 0.37068965517241387);'>regularization</span> <span style=''>scheme</span> <span style=''>that</span> <span style=''>smoothly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>increases</span> <span style=''>th ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Autoencoding</span> <span style=''>topology</span> <br/><br/><span style=''>The</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>learning</span> <span style=''>a</span> <span style=''>manifold</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>on</span> <span style=''>a</span> <span style=''>dataset</span> <span style=''>is</span> <span style=''>framed</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generative</span> <span style=''>model</span> <span style=''>to</span> <span style=''>which</span> <span style=''>we</span> <span style=''>use</span> <span style=''>ideas</span> <span style=''>behind</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>autoencoders</span> <span style=''>(namely</span> <span style=''>adversarialWasserstein</span> <span style=''>autoencoders)</span> <span style=''>to</span> <span style=''>fit</span> <span style=''>deep</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>From</span> <span style=''>a</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>perspective</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resulting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>an</span> <span style=''>atlas</span> <span style=''>of</span> <span style=''>a</span> <span style=''>manifold</span> <span style=''>may</span> <span style=''>be</span> <span style=''>viewed</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combination</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensionality</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reduction</span> <span style=''>and</span> <span style=''>fuzzy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Non</span> <span style='background-color:rgba(255, 0, 0, 0.3956834532374101);'>parametric</span> <span style=''>Bayesian</span> <span style=''>Learning</span> <span style=''>with</span> <span style=''>Deep</span> <span style=''>Learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Structure</span> <span style=''>and</span> <span style=''>Its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Applications</span> <span style=''>in</span> <span style=''>Wireless</span> <span style=''>Networks</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>an</span> <span style=''>infinite</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hierarchical</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.3956834532374101);'>parametric</span> <span style=''>Bayesian</span> <span style=''>model</span> <span style=''>to</span> <span style=''>extract</span> <span style=''>the</span> <span style=''>hidden</span> <span style=''>factors</span> <span style=''>over</span> <span style=''>observed</span> <span style=''>data</span> <span style=''>where</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>hidden</span> <span style=''>factors</span> <span style=''>for</span> <span style=''>each</span> <span style=''>layer</span> <span style=''>is</span> <span style=''>unknown</span> <span style=''>and</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>potentially</span> <span style=''>infinite</span> <span style=''>Moreover</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>layers</span> <span style=''>can</span> <span style=''>also</span> <span style=''>be</span> <span style=''>infinite</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>construct</span> <span style=''>the</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>that</span> <span style=''>allows</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style=''>values</span> <span style=''>for</span> <span style=''>the</span> <span style=''>hidden</span> <span style=''>factors</span> <span style=''>and</span> <span style=''>weights</span> <span style=''>which</span> <span style=''>makes</span> <span style=''>the</span> <span style=''>model</span> <span style=''>suitable</span> <span style=''>for</span> <span style=''>various</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>We</span> <span style=''>use</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.4117647058823529);'>Metropolis</span> <span style=''>Hastings</span> <span style=''>method</span> <span style=''>to</span> <span style=''>infer</span> <span style=''>the</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>Then</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.37823834196891193);'>evaluated</span> <span style=''>by</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>experiments</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Simulation</span> <span style=''>results</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>model</span> <span style=''>fits</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>underlying</span> <span style='background-color:rg ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <span style=''>for</span> <span style=''>Dynamic</span> <span style=''>Problems</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>practical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extensions</span> <span style=''>to</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>for</span> <span style=''>solving</span> <span style=''>dynamic</span> <span style=''>problems</span> <span style=''>We</span> <span style=''>model</span> <span style=''>dynamic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>using</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>spatiotemporal</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style=''>priors</span> <span style=''>which</span> <span style=''>capture</span> <span style=''>all</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>instances</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>over</span> <span style=''>time</span> <span style=''>Our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extensions</span> <span style=''>to</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>use</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>learnt</span> <span style=''>from</span> <span style=''>this</span> <span style=''>model</span> <span style=''>to</span> <span style=''>guide</span> <span style=''>the</span> <span style=''>tracking</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>temporally</span> <span style=''>evolving</span> <span style=''>minimum</span> <span style=''>By</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exploiting</span> <span style=''>temporal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlations</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>method</span> <span style=''>also</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>determines</span> <span style=''>when</span> <span style=''>to</span> <span style=''>make</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluations</span> <span style=''>how</span> <span style=''>fast</span> <span style=''>to</span> <span style=''>make</span> <span style=''>those</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluations</span> <span style=''>and</span> <span style=''>it</span> <span style=''>induces</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>appropriate</span> <span style=''>budget</span> <span style=''>of</span> <span style=''>steps</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>Lastly</span> <span style=''>we</span> <span style=''>evaluate</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technique</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>synthetic</span> <span style=''>and</span> <span style=''>real</span> <span style=''>world</span> <span style=''>problems</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10028756290438534)
# 	segmentation (0.06793673616103522)
# 	information (0.24586628324946083)
# 	architecture (0.0895039539899353)
# 	knowledge (0.12940330697340044)
# 	different (0.2609633357296909)
# 	experimental (0.15240833932422718)
# 	detection (0.12652767792954708)
# 	convolutional (0.1365923795830338)
# 	recognition (0.13191948238677212)
#
# Some Statistics words are:
# 	stochastic (0.13082259663032705)
# 	statistical (0.14172447968285432)
# 	algorithm (0.38701684836471756)
# 	theoretical (0.15213082259663033)
# 	variables (0.14073339940535184)
# 	estimation (0.17393458870168485)
# 	distribution (0.1798810703666997)
# 	dimensional (0.19177403369672943)
# 	inference (0.19970267591674926)
# 	regression (0.17888999008919723)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d2972b4e-7bee-4c30-a5ad-29591a9da868" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d2972b4e-7bee-4c30-a5ad-29591a9da868")) {                    Plotly.newPlot(                        "d2972b4e-7bee-4c30-a5ad-29591a9da868",                        [{"x":["considerable","estimates","algorithm","underlying","bootstrap","algorithms","standpoint","preliminary","solutions","posteriori","computation","precisely","consistency","flexibility","approximate","numerically","alternative","empirical","sketching","computing","difficult","tolerance","longstanding","theoretical","practical","estimation","effectiveness","consequently","randomized","demonstrate","qualitative","transformation","geometric","experimental","asymmetric","represent","outperforms","registration","performance","information","selection","manifolds","particular","efficient","invariant","individually","depending","applications","approximation","essential","representation","distribution","parameterization","additional","distances","minimizing","different","performing","optimization","structures","transformed","comparison","classification","discretization","representing","prediction","crowdsourced","experiments","extraction","nonparametric","satisfaction","originate","associated","extracting","hierarchies","naturalistic","recommendations","personalization","quantitative","highlight","considering","significant","importance","suggestions","providing","important","hierarchy","experience","methodologies","representations","regularizing","including","implementation","strategies","collective","parallelization","effective","distributed","partitioning","introduce","performed","architectures","handwritten","specifically","assumptions","complexity","independent","formulation","publication","kolmogorov","threshold","posteriors","stochastic","incremental","constrained","approximations","assignments","observation","probability","posterior","variational","distributions","integrates","typically","appearing","evaluating","regresses","magnitude","estimating","leveraging","techniques","coefficients","expressions","demonstrating","estimated","unprecedented","collecting","detection","measuring","discriminative","benchmarks","alternatives","intensities","advantage","recognition","conditions","robustness","expression","discriminate","outperform","imbalance","perturbing","separating","characterized","resolution","perturbation","identifying","classifiers","diversification","challenge","dependence","datapoints","misclassified","imbalanced","generalization","challenging","community","corrected","benchmark","numerical","detecting","employing","interpretable","fundamental","clustering","communities","generative","asymptotically","overlapping","memberships","simulated","consistent","recovering","extensive","interesting","beneficial","instances","allocation","individual","dirichlet","intractable","inference","investigate","properties","environments","particularly","streaming","contemporary","objective","attachment","producing","functions","additions","continuous","expressed","succeeded","commentary","treatment","semantics","knowledge","innovation","computational","musicological","discussion","considered","assistant","combinations","transitions","conceptual","arguments","transition","creativity","nontrivial","background","potentially","probabilistic","propensity","factorization","recommender","constraints","inventory","approaches","recommendation","personalized","recommending","candidate","geographical","prevalence","sequential","simultaneously","sequentially","cumulative","exploiting","throughput","surprising","principled","exploitation","increases","formalize","exploration","parallelizing","tra ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	majorization
# 	archetypes
# 	obscuring
# 	missingness
# 	emulating
# 	unsettled
# 	regressionclassification
# 	methylation
# 	adaboosts
# 	discarding
# 	confounders
# 	minimiser
# 	geosciences
# 	spectroradiometer
# 	semiparametric
# 	blockmodel
# 	changepoint
# 	anopheles
# 	repertoire
# 	undersampled
# Some words which never appear in Statistics papers:
# 	naturalistic
# 	diversification
# 	additions
# 	assistant
# 	creativity
# 	fruitfully
# 	polarization
# 	syntactical
# 	contourlet
# 	watermarked
# 	watermarking
# 	discontinuities
# 	watermark
# 	recurrences
# 	entertain
# 	denotational
# 	combinatorics
# 	crossover
# 	definitive
# 	adjectives

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0913812291331766e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7508333333333334
